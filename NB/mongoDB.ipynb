# %%
print("OK")
# Out:
# OK

# %%
# Out:
# syntax: "//" is not a unary operator
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/visa-prediction/NB/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:1
